# %%
# !pip install pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shivank\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\shivank\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\shivank\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
titanic_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

# %% [markdown]
# | Variable  | Definition                              | Key                                   |
# |-----------|------------------------------------------|---------------------------------------|
# | survival  | Survival                                 | 0 = No, 1 = Yes                      |
# | pclass    | Ticket class                             | 1 = 1st, 2 = 2nd, 3 = 3rd           |
# | sex       | Sex                                      | -                                     |
# | age       | Age in years                             | -                                     |
# | sibsp     | # of siblings / spouses aboard Titanic   | -                                     |
# | parch     | # of parents / children aboard Titanic   | -                                     |
# | ticket    | Ticket number                            | -                                     |
# | fare      | Passenger fare                           | -                                     |
# | cabin     | Cabin number                             | -                                     |
# | embarked  | Port of Embarkation                      | C = Cherbourg, Q = Queenstown, S = Southampton |

# %%
# attributes of data
print(f"Shape of dataset:\n{titanic_df.shape}\n")
print(f"Column names:\n{titanic_df.columns}\n")
print(f"Column datatypes:\n{titanic_df.dtypes}\n")
# Out:
# Shape of dataset:
# (891, 12)
#
# Column names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')
#
# Column datatypes:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
women = titanic_df.loc[titanic_df.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)

print("% of women who survived:", rate_women)

men = titanic_df.loc[titanic_df.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)
# Out:
# % of women who survived: 0.7420382165605095
# % of men who survived: 0.18890814558058924

# %%
def process_cabin(df):
    df["HasCabin"] = df["Cabin"].notnull().astype(int)
    df["Deck"] = df["Cabin"].str[0]
    df["Deck"] = df["Deck"].fillna("Unknown")
    return df

# %%
titanic_df = process_cabin(titanic_df)
test_df = process_cabin(test_df)

# %%
from sklearn.ensemble import RandomForestClassifier

y = titanic_df["Survived"]

features = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Deck"]
X = pd.get_dummies(titanic_df[features])
X_test = pd.get_dummies(test_df[features])

X_test = X_test.reindex(columns=X.columns, fill_value=0)

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_df.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
